# %%
import numpy as np
import sympy as sp
import pandas as pd
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
#Generate sample data
df=pd.read_excel('data1.xlsx')
#print(df.head())
x_data=df.Temp
y_data=df.Sales
#print(x_data,y_data)

#Define the function to fit
def fitting(x,a,b,c):
    y=a*x**2+b*x+c
    return y

#Fit the curve to the data

opt,_=curve_fit(fitting,x_data,y_data)

print("a:",opt[0])
print("b:",opt[1])
print("c:",opt[2])

#Plotting the data and best fit curve
plt.scatter(x_data,y_data,label="Data")
plt.plot(x_data,fitting(x_data,opt[0],opt[1],opt[2]),'r-',label="Fitting curve")
plt.legend()
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Curve Fitting example')
plt.show()
# Out:
# a: 0.02609082094163817
# b: 0.5386182934702247
# c: 2.300879120881974

# %%
import numpy as np
import sympy as sp
import pandas as pd
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
#Generate sample data
df=pd.read_excel('data1.xlsx')
#print(df.head())
x_data=df.Temp
y_data=df.Sales
#print(x_data,y_data)

#Define the function to fit
def fitting(x,a,b):
    y=a*x+b
    return y

#Fit the curve to the data

opt,_=curve_fit(fitting,x_data,y_data)

print("a:",opt[0])
print("b:",opt[1])

#Plotting the data and best fit curve
plt.scatter(x_data,y_data,label="Data")
plt.plot(x_data,fitting(x_data,*opt),'r-',label="Fitting curve")
plt.legend()
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Curve Fitting example')
plt.show()
# Out:
# a: 0.9560714271118371
# b: 1.1180952539503872

# %%
import numpy as np
import sympy as sp
import pandas as pd
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
#Generate sample data
df=pd.read_excel('data1.xlsx')
#print(df.head())
x_data=df.Temp
y_data=df.Sales
#print(x_data,y_data)

#Define the function to fit
def fitting(x,a,b,c,d):
    y=a*x**3+b*x**2+c*x+d
    return y

#Fit the curve to the data

opt,_=curve_fit(fitting,x_data,y_data)

print("a:",opt[0])
print("b:",opt[1])
print("c:",opt[2])
print("d:",opt[3])

#Plotting the data and best fit curve
plt.scatter(x_data,y_data,label="Data")
plt.plot(x_data,fitting(x_data,*opt),'r-',label="Fitting curve")
plt.legend()
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Curve Fitting example')
plt.show()
# Out:
# a: 0.003133903131729232
# b: -0.04912285427221996
# c: 1.0356553305085348
# d: 1.533699633700312

# %%
import numpy as np
import sympy as sp
import pandas as pd
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
#Generate sample data
df=pd.read_excel('Book2.xlsx')
#print(df.head())
x_data=df.Pop2000
y_data=df.Pop2010
#print(x_data,y_data)

#Define the function to fit
def fitting(x,a,b):
    y=a*x+b
    return y

#Fit the curve to the data

opt,_=curve_fit(fitting,x_data,y_data)

print("a:",opt[0])
print("b:",opt[1])
#print("c:",opt[2])

#Plotting the data and best fit curve
plt.scatter(x_data,y_data,label="Data")
plt.plot(x_data,fitting(x_data,*opt),'r-',label="Fitting curve")
plt.legend()
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Curve Fitting example')
plt.show()
# Out:
# a: 1.0993306550025403
# b: 0.3165532325210416

# %%
import numpy as np
import sympy as sp
import pandas as pd
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
#Generate sample data
df=pd.read_excel('Book2.xlsx')
#print(df.head())
x_data=df.Pop2000
y_data=df.Pop2010
#print(x_data,y_data)

#Define the function to fit
def fitting(x,a,b,c):
    y=a*x**2+b*x+c
    return y

#Error for quadritic
y_newQuad=fitting(x_data,*opt)
e=y_newQuad-y_data
sse=np.sum(e**2)
error=np.sqrt(sse)
print(error)

y_newLine=fitting1(x_data,*opt)
e1=y_newLine-y_data
sse1=np.sum(e1**2)
error1=np.sqrt(sse1)
print(error1)

#Fit the curve to the data
opt,_=curve_fit(fitting,x_data,y_data)

print("a:",opt[0])
print("b:",opt[1])
print("c:",opt[2])

#Plotting the data and best fit curve
plt.scatter(x_data,y_data,label="Data")
plt.plot(x_data,fitting(x_data,opt[0],opt[1],opt[2]),'r-',label="Fitting curve")
plt.legend()
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Curve Fitting example')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 19
#      16     return y
#      18 #Error for quadritic
# ---> 19 y_newQuad=fitting(x_data,*opt)
#      20 e=y_newQuad-y_data
#      21 sse=np.sum(e**2)
#
# NameError: name 'opt' is not defined
